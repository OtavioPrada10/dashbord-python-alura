# %%
import pandas as pd

# %%
notas = pd.read_csv('https://raw.githubusercontent.com/alura-cursos/data-science-analise-exploratoria/main/Aula_0/ml-latest-small/ratings.csv')
notas
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
notas.shape
# Out:
# (100836, 4)

# %%
notas.columns
# Out:
# Index(['userId', 'movieId', 'rating', 'timestamp'], dtype='object')

# %%
notas.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
notas['rating'].value_counts()
# Out:
# rating
# 4.0    26818
# 3.0    20047
# 5.0    13211
# 3.5    13136
# 4.5     8551
# 2.0     7551
# 2.5     5550
# 1.0     2811
# 1.5     1791
# 0.5     1370
# Name: count, dtype: int64

# %%
notas['rating'].mean()
# Out:
# 3.501556983616962

# %%
notas['rating'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
notas['rating'].median()
# Out:
# 3.5

# %%
filmes = pd.read_csv('https://raw.githubusercontent.com/alura-cursos/data-science-analise-exploratoria/main/Aula_0/ml-latest-small/movies.csv')
filmes.columns = ['filmeId','titulo','generos']
filmes.head()
# Out:
#    filmeId                              titulo  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                        generos
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
notas.query("movieId==1")['rating'].mean()
# Out:
# 3.9209302325581397

# %%
notas.query("movieId==2")['rating'].mean()
# Out:
# 3.4318181818181817

# %%
medias_por_filme = notas.groupby('movieId')['rating'].mean()
medias_por_filme.head()
# Out:
# movieId
# 1    3.920930
# 2    3.431818
# 3    3.259615
# 4    2.357143
# 5    3.071429
# Name: rating, dtype: float64

# %%
medias_por_filme.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
import seaborn as sns
sns.boxplot(medias_por_filme)
# Out:
# <Axes: ylabel='rating'>

# %%
medias_por_filme.describe()
# Out:
# count    9724.000000
# mean        3.262448
# std         0.869874
# min         0.500000
# 25%         2.800000
# 50%         3.416667
# 75%         3.911765
# max         5.000000
# Name: rating, dtype: float64

# %%
sns.distplot(medias_por_filme, kde=False)
# Out:
# <ipython-input-83-2943bc56f38c>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(medias_por_filme, kde=False)
# <Axes: xlabel='rating'>

# %%
medias_por_filme.describe()
# Out:
# count    9724.000000
# mean        3.262448
# std         0.869874
# min         0.500000
# 25%         2.800000
# 50%         3.416667
# 75%         3.911765
# max         5.000000
# Name: rating, dtype: float64

# %%
tmdb = pd.read_csv('https://raw.githubusercontent.com/alura-cursos/data-science-analise-exploratoria/main/Aula_0/tmdb_5000_movies.csv')

# %%
import matplotlib.pyplot as plt
sns.displot(tmdb['revenue'])
plt.title('Titulo Legal')
plt.show()

# %%
# prompt: quero um grafico de distribuição do orçamento dos filmes (budget)

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

tmdb = pd.read_csv('https://raw.githubusercontent.com/alura-cursos/data-science-analise-exploratoria/main/Aula_0/tmdb_5000_movies.csv')

#Criando o gráfico de distribuição do orçamento
sns.displot(tmdb['budget'])
plt.title('Distribuição do Orçamento dos Filmes') #Adicionando um título ao gráfico
plt.show()

# %% [markdown]
# Demostra as informações de cada coluna da tabela

# %%
tmdb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4803 non-null   int64
#  1   genres                4803 non-null   object
#  2   homepage              1712 non-null   object
#  3   id                    4803 non-null   int64
#  4   keywords              4803 non-null   object
#  5   original_language     4803 non-null   object
#  6   original_title        4803 non-null   object
#  7   overview              4800 non-null   object
#  8   popularity            4803 non-null   float64
#  9   production_companies  4803 non-null   object
#  10  production_countries  4803 non-null   object
#  11  release_date          4802 non-null   object
#  12  revenue               4803 non-null   int64
#  13  runtime               4801 non-null   float64
#  14  spoken_languages      4803 non-null   object
# ...

# %%
tmdb.describe()
# Out:
#              budget             id   popularity       revenue      runtime  \
# count  4.803000e+03    4803.000000  4803.000000  4.803000e+03  4801.000000
# mean   2.904504e+07   57165.484281    21.492301  8.226064e+07   106.875859
# std    4.072239e+07   88694.614033    31.816650  1.628571e+08    22.611935
# min    0.000000e+00       5.000000     0.000000  0.000000e+00     0.000000
# 25%    7.900000e+05    9014.500000     4.668070  0.000000e+00    94.000000
# 50%    1.500000e+07   14629.000000    12.921594  1.917000e+07   103.000000
# 75%    4.000000e+07   58610.500000    28.313505  9.291719e+07   118.000000
# max    3.800000e+08  459488.000000   875.581305  2.787965e+09   338.000000
#
#        vote_average    vote_count
# count   4803.000000   4803.000000
# mean       6.092172    690.217989
# std        1.194612   1234.585891
# min        0.000000      0.000000
# 25%        5.600000     54.000000
# 50%        6.200000    235.000000
# 75%        6.800000    737.000000
# ...

# %%
com_faturamento = tmdb.query('revenue > 500')
sns.displot(com_faturamento['revenue'])

# %% [markdown]
# **Busca cada liguagem unica**

# %%
tmdb['original_language'].unique()
# Out:
# array(['en', 'ja', 'fr', 'zh', 'es', 'de', 'hi', 'ru', 'ko', 'te', 'cn',
#        'it', 'nl', 'ta', 'sv', 'th', 'da', 'xx', 'hu', 'cs', 'pt', 'is',
#        'tr', 'nb', 'af', 'pl', 'he', 'ar', 'vi', 'ky', 'id', 'ro', 'fa',
#        'no', 'sl', 'ps', 'el'], dtype=object)

# %% [markdown]
# **Contagem de quantos filmes por linguagem de origem**

# %%
#Contagem de quantos filmes por linguagem de origem
contagem_de_lingua =tmdb['original_language'].value_counts().to_frame().reset_index()
contagem_de_lingua.columns = ['lingua','total']
contagem_de_lingua.head()
# Out:
#   lingua  total
# 0     en   4505
# 1     fr     70
# 2     es     32
# 3     zh     27
# 4     de     27

# %%
sns.barplot(data = contagem_de_lingua, x = 'lingua', y = 'total')
# Out:
# <Axes: xlabel='lingua', ylabel='total'>

# %%
sns.countplot(data=tmdb, x='original_language')
# Out:
# <Axes: xlabel='original_language', ylabel='count'>

# %%
contagem_de_lingua.plot(kind='pie', y="total", labels=contagem_de_lingua['lingua'])
# Out:
# <Axes: ylabel='total'>

# %%
total_por_lingua = tmdb["original_language"].value_counts()
total_geral  = total_por_lingua.sum()
total_de_ingles = total_por_lingua['en']
total_do_resto = total_geral - total_de_ingles
print(total_geral, total_de_ingles, total_do_resto)
# Out:
# 4803 4505 298

# %%
dados = {
"lingua": ["ingles", "outros"],
"totlal": [total_do_resto, total_de_ingles]
}

dados = pd.DataFrame(dados)
dados
# Out:
#    lingua  totlal
# 0  ingles     298
# 1  outros    4505

# %%
sns.barplot(data=dados, y= dados['totlal'], x=dados['lingua'])
# Out:
# <Axes: xlabel='lingua', ylabel='totlal'>

# %%
dados.plot(kind='pie', y="totlal", labels=dados['lingua'])
# Out:
# <Axes: ylabel='totlal'>

# %%
sns.countplot(data=tmdb.query("original_language != 'en'"), x='original_language')
# Out:
# <Axes: xlabel='original_language', ylabel='count'>
